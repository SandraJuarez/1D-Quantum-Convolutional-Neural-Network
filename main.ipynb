# %%
import load_data
import training
import importlib
import numpy as np
import torch
np.random.seed(0)  
torch.manual_seed(0)

# %%
importlib.reload(load_data)
importlib.reload(training)
# Out:
# <module 'training' from 'c:\\Users\\52333\\Documents\\doctorado\\Quantum_1DCNN_Experiments_Colab\\FourierGuidedDesign\\training.py'>

# %%
dataset_list=['mackey']
sample_size_list=[5] #the sample size for each dataset, for euro and legendre this is 5.  For mackey is 4
qubits_list=[4] #in the paper we utilize 2,4,6 or 8 
ansatz_list=['strongly_layers']
kernel_size=2
architecture='super_parallel' #options are no_reupload, parallel and super_parallel
 # if you want to work with parallel ansatz indicate the number of layers in the loop below in variable n_layers

# %%
for d in range(len(dataset_list)):
    dataset=dataset_list[d]
    l=sample_size_list[d]
    out_size = (l + 2*(1) - kernel_size) // 1 + 1 #since paddding and stride are 1
    X_train,Y_train,X_test,Y_test,trainloader,testloader,data=load_data.data(dataset)
    for q in range(len(qubits_list)):
        out_channels=qubits_list[q]
        if architecture=='super_parallel':
            n_layers=out_channels//kernel_size
        elif architecture=='parallel' or architecture=='no_reupload':
            n_layers=4
        for a in range(len(ansatz_list)):
            ansatz=ansatz_list[a]
            run_Name=dataset+ansatz+str(out_channels)+str(n_layers)+str(architecture)
            training.train_testing_phase(X_train,Y_train,X_test,Y_test,kernel_size,n_layers,ansatz,l,out_channels,trainloader,run_Name,dataset,data,architecture)
# Out:
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file 'C:\Users\52333\Documents\doctorado\Quantum_1DCNN_Experiments_Colab\FourierGuidedDesign\mlruns\mlruns\meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\mlflow\store\tracking\file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#   File "c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\mlflow\store\tracking\file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#   File "c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\mlflow\store\tracking\file_store.py", line 1083, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#   File "c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\mlflow\store\tracking\file_store.py", line 1076, in _read_helper
#     result = read_yaml(root, file_name)
#   File "c:\Users\52333\AppData\Local\Programs\Python\Python310\lib\site-packages\mlflow\utils\file_utils.py", line 214, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file 'C:\Users\52333\Documents\doctorado\Quantum_1DCNN_Experiments_Colab\FourierGuidedDesign\mlruns\mlruns\meta.yaml' does not exist.
# Starting epoch 1
# [Epoch 1] loss: 0.144891
# Starting epoch 2
# [Epoch 2] loss: 0.048612
# Starting epoch 3
# [Epoch 3] loss: 0.019918
# Starting epoch 4
# [Epoch 4] loss: 0.009050
# Starting epoch 5
# [Epoch 5] loss: 0.005376
# Starting epoch 6
# [Epoch 6] loss: 0.004298
# Starting epoch 7
# [Epoch 7] loss: 0.003941
# Starting epoch 8
# [Epoch 8] loss: 0.003840
# Starting epoch 9
# [Epoch 9] loss: 0.003768
# Starting epoch 10
# [Epoch 10] loss: 0.003773
# Starting epoch 11
# [Epoch 11] loss: 0.003708
# Starting epoch 12
# [Epoch 12] loss: 0.003697
# Starting epoch 13
# [Epoch 13] loss: 0.003651
# Starting epoch 14
# [Epoch 14] loss: 0.003613
# Starting epoch 15
# [Epoch 15] loss: 0.003639
# Starting epoch 16
# [Epoch 16] loss: 0.003548
# Starting epoch 17
# [Epoch 17] loss: 0.003579
# Starting epoch 18
# [Epoch 18] loss: 0.003550
# Starting epoch 19
# [Epoch 19] loss: 0.003533
# Starting epoch 20
# [Epoch 20] loss: 0.003548
# Starting epoch 21
# [Epoch 21] loss: 0.003472
# Starting epoch 22
# [Epoch 22] loss: 0.003423
# Starting epoch 23
# [Epoch 23] loss: 0.003463
# Starting epoch 24
# [Epoch 24] loss: 0.003417
# Starting epoch 25
# [Epoch 25] loss: 0.003425
# Starting epoch 26
# [Epoch 26] loss: 0.003415
# Starting epoch 27
# [Epoch 27] loss: 0.003367
# Starting epoch 28
# [Epoch 28] loss: 0.003288
# Starting epoch 29
# [Epoch 29] loss: 0.003304
# Starting epoch 30
# [Epoch 30] loss: 0.003249
# Training process has finished.
#  El tiempo de entrenamiento es 999.774022102356
# In the training stage, the RMSE is: 0.006867485270642029
# we begin testing
# RMSE= 0.004135579627003656
# MAE= 0.003155736848909989
# MAPE= 0.00377890298148999
