# %%
import load_data_jax
import training_jax
import importlib
import numpy as np

# %%
importlib.reload(load_data_jax)
importlib.reload(training_jax)
# Out:
# <module 'training_jax' from '/mnt/c/Users/52333/Documents/doctorado/Quantum_1DCNN_Experiments_Colab/FourierGuidedDesign/training_jax.py'>

# %%
dataset_list=['mackey']
sample_size_list=[5] #the sample size for each dataset, for euro and legendre this is 5.  For mackey is 4
qubits_list=[4] #in the paper we utilize 2,4,6 or 8 
ansatz_list=['basic_layers']
key_list=[1]
kernel_size=2
architecture='super_parallel' #options are no_reupload, parallel and super_parallel
 # if you want to work with parallel ansatz indicate the number of layers in the loop below in variable n_layers

# %%
for k in range(len(key_list)):
    key=key_list[k]
    for d in range(len(dataset_list)):
        dataset=dataset_list[d]
        l=sample_size_list[d]
        out_size = (l + 2*(1) - kernel_size) // 1 + 1 #since paddding and stride are 1
    
        X_train,Y_train,X_test,Y_test,trainloader,testloader,data=load_data_jax.data(dataset)
        for q in range(len(qubits_list)):
            out_channels=qubits_list[q]
            if architecture=='super_parallel':
                n_layers=out_channels//kernel_size
            elif architecture=='parallel' or architecture=='no_reupload':
                n_layers=4
            for a in range(len(ansatz_list)):
                ansatz=ansatz_list[a]
                #run_Name=dataset+ansatz+str(out_channels)+str(n_layers)+str(architecture)+str(key)
                run_Name='timeC_varyingqubit_1f_withoutjit_5ep'
                training_jax.train_testing_phase(X_train,Y_train,X_test,Y_test,kernel_size,n_layers,ansatz,l,out_channels,trainloader,testloader,run_Name,dataset,data,architecture,key)
# Out:
# WARNING:root:Malformed experiment 'mlruns'. Detailed error Yaml file '/mnt/c/Users/52333/Documents/doctorado/Quantum_1DCNN_Experiments_Colab/FourierGuidedDesign/mlruns/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/mlflow/store/tracking/file_store.py", line 327, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mlflow/store/tracking/file_store.py", line 421, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mlflow/store/tracking/file_store.py", line 1367, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mlflow/store/tracking/file_store.py", line 1360, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mlflow/utils/file_utils.py", line 309, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/mnt/c/Users/52333/Documents/doctorado/Quantum_1DCNN_Experiments_Colab/FourierGuidedDesign/mlruns/mlruns/meta.yaml' does not exist.
# Param before params: {'weights': Array([[ 1.14115368e-02,  7.21616607e-04, -9.43702123e-04,
#         -6.97571531e-03],
#        [ 1.67136070e-02, -5.31765851e-03, -3.60008327e-04,
#          2.27548912e-02],
#        [ 7.16024226e-05,  6.48655845e-03,  4.71767905e-03,
#          5.01715660e-03]], dtype=float64), 'Dense_0': {'kernel': Array([[-0.68031454,  0.7198001 , -0.5833892 ,  0.27624714],
#        [-0.1363364 ,  0.05705918, -0.0133541 , -0.53759146],
#        [-0.19121315,  0.9709457 ,  0.20002952,  1.0434008 ],
#        [-0.07091755, -0.10099106, -1.0000434 ,  0.05769417]],      dtype=float32), 'bias': Array([0., 0., 0., 0.], dtype=float32)}}
# Starting epoch 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/util.py:302, in cache.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     301   return f(*args, **kwargs)
# --> 302 return cached(config.trace_context() if trace_context_in_key else _ignore(),
#     303               *args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/util.py:296, in cache.<locals>.wrap.<locals>.cached(_, *args, **kwargs)
#     294 @functools.lru_cache(max_size)
#     295 def cached(_, *args, **kwargs):
# --> 296   return f(*args, **kwargs)
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/lax/lax.py:160, in _broadcast_shapes_cached(*shapes)
#     158 @cache()
#     159 def _broadcast_shapes_cached(*shapes: tuple[int, ...]) -> tuple[int, ...]:
# --> 160   return _broadcast_shapes_uncached(*shapes)
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/lax/lax.py:176, in _broadcast_shapes_uncached(*shapes)
#     175 if result_shape is None:
# --> 176   raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}")
#     177 return result_shape
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(64, 4), (64,)]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 19
#      17 #run_Name=dataset+ansatz+str(out_channels)+str(n_layers)+str(architecture)+str(key)
#      18 run_Name='timeC_varyingqubit_1f_withoutjit_5ep'
# ---> 19 training_jax.train_testing_phase(X_train,Y_train,X_test,Y_test,kernel_size,n_layers,ansatz,l,out_channels,trainloader,testloader,run_Name,dataset,data,architecture,key)
#
# File /mnt/c/Users/52333/Documents/doctorado/Quantum_1DCNN_Experiments_Colab/FourierGuidedDesign/training_jax.py:89, in train_testing_phase(X_train, Y_train, X_test, Y_test, kernel_size, n_layers, ansatz, out_size, out_channels, trainloader, testloader, run_Name, dataset, original_dataset, architecture, key)
#      87 inputs = data[0]
#      88 targets = data[1]
# ---> 89 params, opt_state, loss = train_step(params, opt_state, inputs, targets)
#      91 epoch_loss += inputs.shape[0] * loss
#      92 if epoch==29:
#
#     [... skipping hidden 11 frame]
#
# File /mnt/c/Users/52333/Documents/doctorado/Quantum_1DCNN_Experiments_Colab/FourierGuidedDesign/training_jax.py:52, in train_testing_phase.<locals>.train_step(params, opt_state, inputs, targets)
#      50     loss = jnp.mean((predictions - targets) ** 2)
#      51     return loss
# ---> 52 loss, grads = jax.value_and_grad(mse_loss)(params,inputs,targets)
#      53 #print(f"Gradients for QuanvLayer1D: {grads['QuanvLayer1D']}")
#      54 updates, opt_state = opt.update(grads, opt_state)
#
#     [... skipping hidden 8 frame]
#
# File /mnt/c/Users/52333/Documents/doctorado/Quantum_1DCNN_Experiments_Colab/FourierGuidedDesign/training_jax.py:50, in train_testing_phase.<locals>.train_step.<locals>.mse_loss(params, inputs, targets)
#      48 def mse_loss(params,inputs, targets):
#      49     predictions = net.apply(params,inputs)
# ---> 50     loss = jnp.mean((predictions - targets) ** 2)
#      51     return loss
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/numpy/array_methods.py:1036, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1035 def op(self, *args):
# -> 1036   return getattr(self.aval, f"_{name}")(self, *args)
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/numpy/array_methods.py:573, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     571 args = (other, self) if swap else (self, other)
#     572 if isinstance(other, _accepted_binop_types):
# --> 573   return binary_op(*args)
#     574 # Note: don't use isinstance here, because we don't want to raise for
#     575 # subclasses, e.g. NamedTuple objects that may override operators.
#     576 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 11 frame]
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/numpy/ufuncs.py:749, in subtract(x, y)
#     746 @implements(np.subtract, module='numpy')
#     747 @partial(jit, inline=True)
#     748 def subtract(x: ArrayLike, y: ArrayLike, /) -> Array:
# --> 749   return lax.sub(*promote_args("subtract", x, y))
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/numpy/util.py:368, in promote_args(fun_name, *args)
#     366 _check_no_float0s(fun_name, *args)
#     367 check_for_prngkeys(fun_name, *args)
# --> 368 return promote_shapes(fun_name, *promote_dtypes(*args))
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/numpy/util.py:238, in promote_shapes(fun_name, *args)
#     236 if config.numpy_rank_promotion.value != "allow":
#     237   _rank_promotion_warning_or_error(fun_name, shapes)
# --> 238 result_rank = len(lax.broadcast_shapes(*shapes))
#     239 return [lax.broadcast_to_rank(arg, result_rank) for arg in args]
#
#     [... skipping hidden 1 frame]
#
# File /usr/local/lib/python3.11/dist-packages/jax/_src/lax/lax.py:176, in _broadcast_shapes_uncached(*shapes)
#     174 result_shape = _try_broadcast_shapes(shape_list)
#     175 if result_shape is None:
# --> 176   raise ValueError(f"Incompatible shapes for broadcasting: shapes={list(shapes)}")
#     177 return result_shape
#
# ValueError: Incompatible shapes for broadcasting: shapes=[(64, 4), (64,)]
